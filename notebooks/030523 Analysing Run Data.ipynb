# %%
import numpy as np 
import matplotlib.pyplot as plt
import csv

# %%
prefix = '/home/ucapvdw/Projects/project-orthogonal_classifiers/tanh_data/'

prefix_18 = prefix +'02052023131945/'
prefix_24 = prefix + '02052023132730/'

# %%
with open(prefix_18 + 'run_data.csv', 'r') as f:
    data_18 = np.loadtxt(f, delimiter=',')
with open(prefix_24 + 'run_data.csv', 'r') as f:
    data_24 = np.loadtxt(f, delimiter=',')

# %% [markdown]
# ## Job 6818 Results

# %%
steps = range(len(data_18))
plt.figure(facecolor='white')
plt.plot(steps, data_18[:, 0], 'x-')
plt.title('Job 613818: Accuracy')
# Out:
# Text(0.5, 1.0, 'Job 613818: Accuracy')

# %%
plt.figure(facecolor='white')
plt.plot(steps, data_18[:, 1], 'x-')
plt.title('Job 613818: Costs')
# Out:
# Text(0.5, 1.0, 'Job 613818: Costs')

# %%
plt.figure(facecolor='white')
plt.plot(steps, data_18[:, 2], 'x-')
plt.title('Job 613818: Learning Rates')
# Out:
# Text(0.5, 1.0, 'Job 613818: Learning Rates')

# %% [markdown]
# ## Job 613824 Results

# %%
plt.figure(facecolor='white')
plt.plot(steps, data_24[:, 0], 'x-')
plt.title('Job 613824: Accuracy')
# Out:
# Text(0.5, 1.0, 'Job 613824: Accuracy')

# %%
plt.figure(facecolor='white')
plt.plot(steps, data_24[:, 1], 'x-')
plt.title('Job 613824: Cost')
# Out:
# Text(0.5, 1.0, 'Job 613824: Cost')

# %%
plt.figure(facecolor='white')
plt.plot(steps, data_24[:, 2], 'x-')
plt.title('Job 613824: Learning Rate')
# Out:
# Text(0.5, 1.0, 'Job 613824: Learning Rate')
